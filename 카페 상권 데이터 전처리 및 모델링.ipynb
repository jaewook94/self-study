# %%
import pandas as pd
from pandas import DataFrame

# %%
df = pd.read_excel('./8.27_상권_데이터_수정본.xlsx')
df = pd.DataFrame(df)

# %%
df
# Out:
#        상권_구분_코드_명 시군구명       총_매출_금액   점포수   개업_율  폐업_률  폐업_점포_수  프랜차이즈_점포_수  \
# 0             계동길  종로구  2.306165e+09  95.0   4.00   3.0     0.75         4.0
# 1          난계로27길  종로구  6.557127e+08  20.0   0.00   0.0     0.00         1.0
# 2        돈화문로11가길  종로구  1.155523e+09  73.0   4.25   1.5     0.25         1.0
# 3             명륜길  종로구  5.653390e+07  24.0   0.00   0.0     0.00         1.0
# 4            백석동길  종로구  1.580058e+09  22.0   4.25   5.0     0.25         0.0
# ...           ...  ...           ...   ...    ...   ...      ...         ...
# 1539   창동상계_경제기반형  NaN           NaN   NaN   4.00   1.0     1.00        38.0
# 1540  세운상가_중심시가지형  NaN           NaN   NaN   6.00   4.0     3.00         7.0
# 1541  창덕궁앞_중심시가지형  NaN           NaN   NaN   8.00   1.0     1.00        10.0
# 1542     신촌_일반근린형  NaN           NaN   NaN   3.00   3.0     5.00        60.0
# 1543   창신숭인_일반근린형  NaN           NaN   NaN  12.00   6.0     2.00         7.0
#
# ...

# %%
df.shape
# Out:
# (1544, 45)

# %%
# 데이터 drop할거라서 복사해놓음
s1df = df.copy()

# %%
# 결측치 제거
s1df.isnull().sum()
# Out:
# 상권_구분_코드_명             0
# 시군구명                  48
# 총_매출_금액              357
# 점포수                  357
# 개업_율                  56
# 폐업_률                  56
# 폐업_점포_수               56
# 프랜차이즈_점포_수            56
# 주중_매출_금액             357
# 주말_매출_금액             357
# 시간대_06~11_매출_금액      357
# 시간대_11~14_매출_금액      357
# 시간대_14~17_매출_금액      357
# 시간대_17~21_매출_금액      357
# 연령대_10_매출_금액         357
# 연령대_20_매출_금액         357
# 연령대_30_매출_금액         357
# 연령대_40_매출_금액         357
# 연령대_50_매출_금액         357
# 연령대_60_이상_매출_금액      357
# 아파트_단지_수             235
# 아파트_평균_면적            235
# 아파트_평균_시가            235
# 상권_변화_지표              48
# 상권_변화_지표_명            48
# 운영_영업_개월_평균           48
# 폐업_영업_개월_평균           48
# 총 상주인구 수              62
# 총 가구 수                62
# 총_생활인구_수              62
# 연령대_10_생활인구_수         62
# 연령대_20_생활인구_수         62
# 연령대_30_생활인구_수         62
# 연령대_40_생활인구_수         62
# 연령대_50_생활인구_수         62
# 연령대_60_이상_생활인구_수      62
# 주중_생활인구_수             62
# ...

# %%
s1df = s1df.dropna()

# %%
s1df.shape
# Out:
# (1086, 45)

# %%
# 구별 상관관계 요소 상위 5개 구하기(매출 데이터 제외)
s1df_c = s1df.drop(['점포수', '폐업_점포_수', '프랜차이즈_점포_수', '주중_매출_금액',
                   '주말_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
                   '시간대_14~17_매출_금액', '시간대_17~21_매출_금액','연령대_10_매출_금액',
                   '연령대_20_매출_금액', '연령대_30_매출_금액', '연령대_40_매출_금액',
                   '연령대_50_매출_금액', '연령대_60_이상_매출_금액'], axis=1)
s1df_c.sample(5)
# Out:
#         상권_구분_코드_명  시군구명       총_매출_금액  개업_율   폐업_률  아파트_단지_수  아파트_평균_면적  \
# 1086  서울 강남구 선릉역_2   강남구  2.322881e+10  4.00   3.50      49.0       38.0
# 423         증산로17길   은평구  1.214530e+07  8.25   0.00      40.0       57.0
# 56          백범로79길   용산구  1.144765e+09  2.25   2.50     104.0       59.0
# 241         면목로33길   중랑구  2.627602e+08  4.25  10.00      21.0       47.0
# 180         망우로21길  동대문구  4.665563e+08  0.00   6.25       4.0       52.0
#
#         아파트_평균_시가 상권_변화_지표 상권_변화_지표_명  ...  연령대_60_이상_생활인구_수   주중_생활인구_수  \
# 1086  200869407.0       LL       다이나믹  ...         211406.25  1216483.25
# 423   149900389.0       LH       상권확장  ...         141557.25   349705.25
# 56    242145926.0       HH         정체  ...         235145.00   889915.00
# 241   147093552.0       HL       상권축소  ...         386490.25  1056742.00
# 180   207921429.0       HH         정체  ...          59304.00   209856.25
#
#       주말_생활인구_수  총_직장_인구_수  연령대_10_직장_인구_수  연령대_20_직장_인구_수  연령대_30_직장_인구_수  \
# ...

# %%
s1df.shape
# Out:
# (1086, 45)

# %%
#s1df drop 후
s1df_c.shape
# Out:
# (1086, 30)

# %%
s1df_c.columns
# Out:
# Index(['상권_구분_코드_명', '시군구명', '총_매출_금액', '개업_율', '폐업_률', '아파트_단지_수',
#        '아파트_평균_면적', '아파트_평균_시가', '상권_변화_지표', '상권_변화_지표_명', '운영_영업_개월_평균',
#        '폐업_영업_개월_평균', '총 상주인구 수', '총 가구 수', '총_생활인구_수', '연령대_10_생활인구_수',
#        '연령대_20_생활인구_수', '연령대_30_생활인구_수', '연령대_40_생활인구_수', '연령대_50_생활인구_수',
#        '연령대_60_이상_생활인구_수', '주중_생활인구_수', '주말_생활인구_수', '총_직장_인구_수',
#        '연령대_10_직장_인구_수', '연령대_20_직장_인구_수', '연령대_30_직장_인구_수', '연령대_40_직장_인구_수',
#        '연령대_50_직장_인구_수', '연령대_60_이상_직장_인구_수'],
#       dtype='object')

# %%
a = s1df_c['시군구명']

# %%
a
# Out:
# 0       종로구
# 1       종로구
# 2       종로구
# 3       종로구
# 4       종로구
#        ...
# 1489    강동구
# 1490    용산구
# 1492     중구
# 1493    종로구
# 1494    송파구
# Name: 시군구명, Length: 1086, dtype: object

# %%
a.unique() # 길이 25
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
s1df_c[s1df_c['시군구명'] == a.unique()[2]]
# Out:
#         상권_구분_코드_명 시군구명       총_매출_금액   개업_율   폐업_률  아파트_단지_수  아파트_평균_면적  \
# 49        녹사평대로11길  용산구  9.884886e+07   0.00   0.00       4.0       63.0
# 50        녹사평대로26길  용산구  1.636684e+09   6.00  16.75      10.0       61.0
# 51        녹사평대로32길  용산구  5.599261e+08   6.75   0.00       8.0       65.0
# 52       녹사평대로40나길  용산구  6.306454e+08   8.25   6.00       9.0      111.0
# 53        녹사평대로46길  용산구  7.744485e+08   9.00  16.75      22.0       75.0
# 54         대사관로34길  용산구  2.608970e+08   0.00  12.50      35.0       47.0
# 55         두텁바위로1길  용산구  1.302654e+08   6.25   0.00      38.0       62.0
# 56          백범로79길  용산구  1.144765e+09   2.25   2.50     104.0       59.0
# 57          백범로90길  용산구  2.310650e+08   0.00   0.00      11.0       75.0
# 59          소월로20길  용산구  2.582700e+08   6.75  12.25      44.0       49.0
# 60          신흥로20길  용산구  9.390649e+08  15.50  10.00     114.0       49.0
# 61         우사단로10길  용산구  8.167307e+07   4.25   0.00      49.0       61.0
# ...

# %%
corr = s1df_c[s1df_c['시군구명'] == a.unique()[2]].corr(method='pearson')
corr
# Out:
#                     총_매출_금액      개업_율      폐업_률  아파트_단지_수  아파트_평균_면적  \
# 총_매출_금액            1.000000 -0.099792 -0.041134  0.029823   0.254122
# 개업_율              -0.099792  1.000000  0.491820  0.216303  -0.104676
# 폐업_률              -0.041134  0.491820  1.000000  0.092275  -0.060583
# 아파트_단지_수           0.029823  0.216303  0.092275  1.000000  -0.108549
# 아파트_평균_면적          0.254122 -0.104676 -0.060583 -0.108549   1.000000
# 아파트_평균_시가          0.148307 -0.234788 -0.076883 -0.263704   0.584917
# 운영_영업_개월_평균       -0.011615  0.004908 -0.148233 -0.062185  -0.159492
# 폐업_영업_개월_평균       -0.002800  0.104900 -0.115418  0.082009  -0.176395
# 총 상주인구 수           0.250209  0.029076 -0.043860  0.790338   0.040326
# 총 가구 수             0.377632 -0.004131 -0.059546  0.716334   0.078894
# 총_생활인구_수           0.238830  0.048429  0.005614  0.647069  -0.117499
# 연령대_10_생활인구_수     -0.038426  0.059169 -0.012871  0.657277  -0.165924
# 연령대_20_생활인구_수      0.453924  0.043466  0.020748  0.494177  -0.031483
# ...

# %%
len(s1df_c)
# Out:
# 1086

# %%
for i in s1df_c:
    print(i)
# Out:
# 상권_구분_코드_명
# 시군구명
# 총_매출_금액
# 개업_율
# 폐업_률
# 아파트_단지_수
# 아파트_평균_면적
# 아파트_평균_시가
# 상권_변화_지표
# 상권_변화_지표_명
# 운영_영업_개월_평균
# 폐업_영업_개월_평균
# 총 상주인구 수
# 총 가구 수
# 총_생활인구_수
# 연령대_10_생활인구_수
# 연령대_20_생활인구_수
# 연령대_30_생활인구_수
# 연령대_40_생활인구_수
# 연령대_50_생활인구_수
# 연령대_60_이상_생활인구_수
# 주중_생활인구_수
# 주말_생활인구_수
# 총_직장_인구_수
# 연령대_10_직장_인구_수
# 연령대_20_직장_인구_수
# 연령대_30_직장_인구_수
# 연령대_40_직장_인구_수
# 연령대_50_직장_인구_수
# 연령대_60_이상_직장_인구_수

# %%
for i,element in enumerate(s1df_c):
    print(i,element)
# Out:
# 0 상권_구분_코드_명
# 1 시군구명
# 2 총_매출_금액
# 3 개업_율
# 4 폐업_률
# 5 아파트_단지_수
# 6 아파트_평균_면적
# 7 아파트_평균_시가
# 8 상권_변화_지표
# 9 상권_변화_지표_명
# 10 운영_영업_개월_평균
# 11 폐업_영업_개월_평균
# 12 총 상주인구 수
# 13 총 가구 수
# 14 총_생활인구_수
# 15 연령대_10_생활인구_수
# 16 연령대_20_생활인구_수
# 17 연령대_30_생활인구_수
# 18 연령대_40_생활인구_수
# 19 연령대_50_생활인구_수
# 20 연령대_60_이상_생활인구_수
# 21 주중_생활인구_수
# 22 주말_생활인구_수
# 23 총_직장_인구_수
# 24 연령대_10_직장_인구_수
# 25 연령대_20_직장_인구_수
# 26 연령대_30_직장_인구_수
# 27 연령대_40_직장_인구_수
# 28 연령대_50_직장_인구_수
# 29 연령대_60_이상_직장_인구_수

# %%
rank = corr['총_매출_금액'][corr['총_매출_금액'].rank()>=10]

# %%
a = s1df_c['시군구명'] # 항상 같으니깐 빼야함!
for i,element in enumerate(s1df_c):
    corr = s1df_c[s1df_c['시군구명']==a.unique()[i-1]].corr(method='pearson')
    rank = corr['총_매출_금액'][corr['총_매출_금액'].rank()>=10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-b911775ebcc7> in <module>
#       1 a = s1df_c['시군구명'] # 항상 같으니깐 빼야함!
#       2 for i,element in enumerate(s1df_c):
# ----> 3     corr = s1df_c[s1df_c['시군구명']==a.unique()[i-1]].corr(method='pearson')
#       4     rank = corr['총_매출_금액'][corr['총_매출_금액'].rank()>=10]
#
# IndexError: index 25 is out of bounds for axis 0 with size 25

# %%
s1df_c[s1df_c['시군구명']==a.unique()[0]]
# Out:
#           상권_구분_코드_명 시군구명       총_매출_금액   개업_율   폐업_률  아파트_단지_수  아파트_평균_면적  \
# 0                계동길  종로구  2.306165e+09   4.00   3.00      26.0       69.0
# 1             난계로27길  종로구  6.557127e+08   0.00   0.00       5.0       15.0
# 2           돈화문로11가길  종로구  1.155523e+09   4.25   1.50       5.0       35.0
# 3                명륜길  종로구  5.653390e+07   0.00   0.00      41.0       51.0
# 4               백석동길  종로구  1.580058e+09   4.25   5.00      41.0       84.0
# 5             북촌로11길  종로구  9.003951e+07   0.00   6.25       3.0       77.0
# 6              북촌로5길  종로구  1.057260e+10   2.25   2.25       2.0      131.0
# 7             북촌로5나길  종로구  1.550302e+09   0.00   2.75       5.0      118.0
# 8              삼청로5길  종로구  1.926192e+09   2.75   0.00       1.0      175.0
# 9             성균관로5길  종로구  5.388050e+08   0.00   2.00      12.0       49.0
# 10              숭인동길  종로구  1.631448e+08  26.75  25.00      19.0       52.0
# ...

# %%
a=s1df_c.loc[:,'시군구명']
corr =s1df_c[s1df_c['시군구명']==a.unique()[0]].corr(method='pearson')
corr['총_매출_금액'][corr['총_매출_금액'].rank()>=10]
# Out:
# 총_매출_금액              1.000000
# 아파트_평균_면적            0.357993
# 아파트_평균_시가            0.548101
# 총_생활인구_수             0.496840
# 연령대_20_생활인구_수        0.431704
# 연령대_30_생활인구_수        0.577166
# 연령대_40_생활인구_수        0.557804
# 연령대_50_생활인구_수        0.489894
# 연령대_60_이상_생활인구_수     0.437920
# 주중_생활인구_수            0.520219
# 주말_생활인구_수            0.388993
# 총_직장_인구_수            0.776166
# 연령대_20_직장_인구_수       0.555876
# 연령대_30_직장_인구_수       0.810266
# 연령대_40_직장_인구_수       0.830451
# 연령대_50_직장_인구_수       0.778668
# 연령대_60_이상_직장_인구_수    0.676145
# Name: 총_매출_금액, dtype: float64

# %%
# 구별로 묶기
# 합계 열 grouping
s1df_sum_group = s1df.groupby(['시군구명'])['점포수','프랜차이즈_점포_수','폐업_점포_수', '총_매출_금액', '주중_매출_금액',
                      '주말_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
                      '시간대_14~17_매출_금액', '시간대_17~21_매출_금액','연령대_10_매출_금액',
                      '연령대_20_매출_금액', '연령대_30_매출_금액', '연령대_40_매출_금액',
                      '연령대_50_매출_금액', '연령대_60_이상_매출_금액','아파트_단지_수',
                      '총 상주인구 수', '총 가구 수', '총_생활인구_수', '연령대_10_생활인구_수',
                      '연령대_20_생활인구_수', '연령대_30_생활인구_수', '연령대_40_생활인구_수',
                      '연령대_50_생활인구_수', '연령대_60_이상_생활인구_수', '주중_생활인구_수',
                      '주말_생활인구_수', '총_직장_인구_수', '연령대_10_직장_인구_수',
                      '연령대_20_직장_인구_수', '연령대_30_직장_인구_수', '연령대_40_직장_인구_수',
                      '연령대_50_직장_인구_수', '연령대_60_이상_직장_인구_수'].sum()
# Out:
# <ipython-input-11-d2d819d8f488>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   s1df_sum_group = s1df.groupby(['시군구명'])['점포수','프랜차이즈_점포_수','폐업_점포_수', '총_매출_금액', '주중_매출_금액',

# %%
# 평균 열 grouping
s1df_mean_group = s1df.groupby(['시군구명'])['개업_율', '폐업_률', '아파트_평균_면적',
                                        '아파트_평균_시가', '운영_영업_개월_평균',
                                        '폐업_영업_개월_평균'].mean()
# Out:
# <ipython-input-12-d5e6856df98e>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   s1df_mean_group = s1df.groupby(['시군구명'])['개업_율', '폐업_률', '아파트_평균_면적',

# %%
s2df = pd.concat([s1df_sum_group,s1df_mean_group], axis=1)

# %%
# 총매출 제외 매출 칼럼 제거
s3df = s2df.drop(['주중_매출_금액', '주말_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
          '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '연령대_10_매출_금액',
          '연령대_20_매출_금액', '연령대_30_매출_금액', '연령대_40_매출_금액',
          '연령대_50_매출_금액', '연령대_60_이상_매출_금액'], axis=1)

# %%
# 상관관계 분석
corr = s3df.corr(method='pearson')

# %%
s3df.iloc[2].corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-56badf66c813> in <module>
# ----> 1 s3df.iloc[2].corr(method='pearson')
#
# TypeError: corr() missing 1 required positional argument: 'other'

# %%
corr.iloc[3][corr.iloc[3]>0.5]
# Out:
# 점포수                  0.981904
# 프랜차이즈_점포_수           0.964942
# 폐업_점포_수              0.950983
# 총_매출_금액              1.000000
# 총_생활인구_수             0.523625
# 연령대_20_생활인구_수        0.553799
# 연령대_30_생활인구_수        0.708961
# 연령대_40_생활인구_수        0.683687
# 주중_생활인구_수            0.583187
# 총_직장_인구_수            0.934587
# 연령대_10_직장_인구_수       0.882849
# 연령대_20_직장_인구_수       0.934138
# 연령대_30_직장_인구_수       0.931444
# 연령대_40_직장_인구_수       0.932311
# 연령대_50_직장_인구_수       0.932687
# 연령대_60_이상_직장_인구_수    0.895828
# 아파트_평균_면적            0.601386
# 아파트_평균_시가            0.753932
# Name: 총_매출_금액, dtype: float64

# %%
corr
# Out:
#                         점포수  프랜차이즈_점포_수   폐업_점포_수   총_매출_금액  아파트_단지_수  \
# 점포수                1.000000    0.956655  0.966139  0.981904  0.191778
# 프랜차이즈_점포_수         0.956655    1.000000  0.888553  0.964942  0.154318
# 폐업_점포_수            0.966139    0.888553  1.000000  0.950983  0.303992
# 총_매출_금액            0.981904    0.964942  0.950983  1.000000  0.173494
# 아파트_단지_수           0.191778    0.154318  0.303992  0.173494  1.000000
# 총 상주인구 수           0.117432    0.106822  0.249742  0.089698  0.805158
# 총 가구 수             0.173714    0.163192  0.308167  0.151527  0.709194
# 총_생활인구_수           0.546757    0.514112  0.648605  0.523625  0.693271
# 연령대_10_생활인구_수      0.268297    0.227323  0.390943  0.244145  0.819567
# 연령대_20_생활인구_수      0.573618    0.513194  0.692857  0.553799  0.493455
# 연령대_30_생활인구_수      0.715070    0.689788  0.806313  0.708961  0.634167
# 연령대_40_생활인구_수      0.697716    0.677505  0.773070  0.683687  0.671671
# ...
