# %%
"""Utilities and tools for tracking runs with Weights & Biases."""

import logging
import os
import sys
from contextlib import contextmanager
from pathlib import Path

import yaml
from tqdm import tqdm

FILE = Path(__file__).absolute()
sys.path.append(FILE.parents[3].as_posix())  # add yolov5/ to path

from utils.datasets import LoadImagesAndLabels
from utils.datasets import img2label_paths
from utils.general import check_dataset, check_file

try:
    import wandb

    assert hasattr(wandb, '__version__')  # verify package import not local dir
except (ImportError, AssertionError):
    wandb = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f6e2585ce47c> in <module>
#      10 from tqdm import tqdm
#      11
# ---> 12 FILE = Path(__file__).absolute()
#      13 sys.path.append(FILE.parents[3].as_posix())  # add yolov5/ to path
#      14
#
# NameError: name '__file__' is not defined

# %%
os.path.join(os.path.dirname(__file__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-792e72ea47fc> in <module>
# ----> 1 os.path.join(os.path.dirname(__file__))
#
# NameError: name '__file__' is not defined

# %%
print(os.getcwd())
print(sys.argv[0])
print(os.path.dirname(os.path.realpath('__file__')))
# Out:
# C:\git\self-study
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py
# C:\git\self-study

# %%
def all_logging_disabled(highest_level=logging.CRITICAL):
    """ source - https://gist.github.com/simon-weber/7853144
    A context manager that will prevent any logging messages triggered during the body from being processed.
    :param highest_level: the maximum logging level in use.
      This would only need to be changed if a custom level greater than CRITICAL is defined.
    """
    previous_level = logging.root.manager.disable
    logging.disable(highest_level)
    try:
        yield
    finally:
        logging.disable(previous_level)

# %%
wandb_utils.py
    - class WandbLogger():

# %%
import wandb

# %%
wandb.init()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ········
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\재욱/.netrc
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.1<br/>
#                 Syncing run <strong style="color:#cdcd00">zany-snowball-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jaewooklee/self-study" target="_blank">https://wandb.ai/jaewooklee/self-study</a><br/>
#                 Run page: <a href="https://wandb.ai/jaewooklee/self-study/runs/3b5c08eg" target="_blank">https://wandb.ai/jaewooklee/self-study/runs/3b5c08eg</a><br/>
#                 Run data is saved locally in <code>C:\git\self-study\wandb\run-20210809_184345-3b5c08eg</code><br/><br/>
# <h1>Run(3b5c08eg)</h1><iframe src="https://wandb.ai/jaewooklee/self-study/runs/3b5c08eg" style="border:none;width:100%;height:400px"></iframe>

# %%
artifact = wandb.Artifact('mnist', type='dataset')
artifact.add_dir('./mnist')
wandb.log_artifact(artifact)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-d8cc890f074e> in <module>
#       1 artifact = wandb.Artifact('mnist', type='dataset')
# ----> 2 artifact.add_dir('./mnist')
#       3 wandb.log_artifact(artifact)
#
# C:\anaconda3\lib\site-packages\wandb\sdk\wandb_artifacts.py in add_dir(self, local_path, name)
#     386         self._ensure_can_add()
#     387         if not os.path.isdir(local_path):
# --> 388             raise ValueError("Path is not a directory: %s" % local_path)
#     389
#     390         termlog(
#
# ValueError: Path is not a directory: ./mnist
